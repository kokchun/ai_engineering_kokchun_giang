# %% [markdown]
# # Random forest

# %%
import pandas as pd

df = pd.read_csv("../../data/Heart.csv", index_col=0)
df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1   63    1       typical     145   233    1        2    150      0      2.3
# 2   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4   37    1    nonanginal     130   250    0        0    187      0      3.5
# 5   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 1      3  0.0       fixed   No
# 2      2  3.0      normal  Yes
# 3      2  2.0  reversable  Yes
# 4      3  0.0      normal   No
# 5      1  0.0      normal   No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 303 entries, 1 to 303
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 35.5+ KB

# %%
df_no_nulls = df.dropna()

df_no_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 1 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        297 non-null    int64
#  1   Sex        297 non-null    int64
#  2   ChestPain  297 non-null    object
#  3   RestBP     297 non-null    int64
#  4   Chol       297 non-null    int64
#  5   Fbs        297 non-null    int64
#  6   RestECG    297 non-null    int64
#  7   MaxHR      297 non-null    int64
#  8   ExAng      297 non-null    int64
#  9   Oldpeak    297 non-null    float64
#  10  Slope      297 non-null    int64
#  11  Ca         297 non-null    float64
#  12  Thal       297 non-null    object
#  13  AHD        297 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 34.8+ KB

# %%
df_no_nulls["AHD"].value_counts()
# Out:
# AHD
# No     160
# Yes    137
# Name: count, dtype: int64

# %%
df_dummies = pd.get_dummies(df_no_nulls, drop_first=True)
df_dummies.head()
# Out:
#    Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope   Ca  \
# 1   63    1     145   233    1        2    150      0      2.3      3  0.0
# 2   67    1     160   286    0        2    108      1      1.5      2  3.0
# 3   67    1     120   229    0        2    129      1      2.6      2  2.0
# 4   37    1     130   250    0        0    187      0      3.5      3  0.0
# 5   41    0     130   204    0        2    172      0      1.4      1  0.0
#
#    ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical  Thal_normal  \
# 1                 False                 False               True        False
# 2                 False                 False              False         True
# 3                 False                 False              False        False
# 4                  True                 False              False         True
# 5                 False                  True              False         True
#
#    Thal_reversable  AHD_Yes
# 1            False    False
# 2            False     True
# 3             True     True
# 4            False    False
# 5            False    False

# %% [markdown]
# ## split data

# %%
X, y = df_dummies.drop("AHD_Yes", axis=1), df_dummies["AHD_Yes"]
X.head()
# Out:
#    Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope   Ca  \
# 1   63    1     145   233    1        2    150      0      2.3      3  0.0
# 2   67    1     160   286    0        2    108      1      1.5      2  3.0
# 3   67    1     120   229    0        2    129      1      2.6      2  2.0
# 4   37    1     130   250    0        0    187      0      3.5      3  0.0
# 5   41    0     130   204    0        2    172      0      1.4      1  0.0
#
#    ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical  Thal_normal  \
# 1                 False                 False               True        False
# 2                 False                 False              False         True
# 3                 False                 False              False        False
# 4                  True                 False              False         True
# 5                 False                  True              False         True
#
#    Thal_reversable
# 1            False
# 2            False
# 3             True
# 4            False
# 5            False

# %%
y.head()
# Out:
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# Name: AHD_Yes, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((198, 16), (99, 16))

# %% [markdown]
# ## model training
#
# - note no feature scaling for Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred[:10]
# Out:
# array([False,  True, False,  True, False, False,  True,  True,  True,
#        False])

# %%
y_test[:10].values
# Out:
# array([False,  True, False,  True, False, False, False, False,  True,
#        False])

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report


print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot();
# Out:
#               precision    recall  f1-score   support
#
#        False       0.84      0.87      0.85        53
#         True       0.84      0.80      0.82        46
#
#     accuracy                           0.84        99
#    macro avg       0.84      0.84      0.84        99
# weighted avg       0.84      0.84      0.84        99

# %% [markdown]
# ## Feature importance

# %%
model.feature_importances_
# Out:
# array([0.09457031, 0.02293966, 0.06644741, 0.09433056, 0.01147383,
#        0.02500978, 0.11915709, 0.03007908, 0.10423206, 0.02189123,
#        0.17166698, 0.05249987, 0.00865858, 0.01723194, 0.10197775,
#        0.05783387])

# %%
model.feature_importances_.shape
# Out:
# (16,)

# %%
X.columns
# Out:
# Index(['Age', 'Sex', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR', 'ExAng',
#        'Oldpeak', 'Slope', 'Ca', 'ChestPain_nonanginal',
#        'ChestPain_nontypical', 'ChestPain_typical', 'Thal_normal',
#        'Thal_reversable'],
#       dtype='object')

# %%
len(X.columns), len(model.feature_importances_)
# Out:
# (16, 16)

# %%
feature_importance = pd.DataFrame([X.columns, model.feature_importances_])
feature_importance
# Out:
#         0        1         2         3         4        5         6   \
# 0      Age      Sex    RestBP      Chol       Fbs  RestECG     MaxHR
# 1  0.09457  0.02294  0.066447  0.094331  0.011474  0.02501  0.119157
#
#          7         8         9         10                    11  \
# 0     ExAng   Oldpeak     Slope        Ca  ChestPain_nonanginal
# 1  0.030079  0.104232  0.021891  0.171667                0.0525
#
#                      12                 13           14               15
# 0  ChestPain_nontypical  ChestPain_typical  Thal_normal  Thal_reversable
# 1              0.008659           0.017232     0.101978         0.057834

# %%
feature_importance = feature_importance.T
feature_importance.columns = ["Feature", "Importance"]

# %%
feature_importance
# Out:
#                  Feature Importance
# 0                    Age    0.09457
# 1                    Sex    0.02294
# 2                 RestBP   0.066447
# 3                   Chol   0.094331
# 4                    Fbs   0.011474
# 5                RestECG    0.02501
# 6                  MaxHR   0.119157
# 7                  ExAng   0.030079
# 8                Oldpeak   0.104232
# 9                  Slope   0.021891
# 10                    Ca   0.171667
# 11  ChestPain_nonanginal     0.0525
# 12  ChestPain_nontypical   0.008659
# 13     ChestPain_typical   0.017232
# 14           Thal_normal   0.101978
# 15       Thal_reversable   0.057834

# %%
feature_importance = feature_importance.sort_values(by = "Importance", ascending=False)
feature_importance
# Out:
#                  Feature Importance
# 10                    Ca   0.171667
# 6                  MaxHR   0.119157
# 8                Oldpeak   0.104232
# 14           Thal_normal   0.101978
# 0                    Age    0.09457
# 3                   Chol   0.094331
# 2                 RestBP   0.066447
# 15       Thal_reversable   0.057834
# 11  ChestPain_nonanginal     0.0525
# 7                  ExAng   0.030079
# 5                RestECG    0.02501
# 1                    Sex    0.02294
# 9                  Slope   0.021891
# 13     ChestPain_typical   0.017232
# 4                    Fbs   0.011474
# 12  ChestPain_nontypical   0.008659

# %%
feature_importance["Importance"].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
ax = feature_importance.plot(y="Importance", x="Feature", kind="barh")
ax.invert_yaxis()
