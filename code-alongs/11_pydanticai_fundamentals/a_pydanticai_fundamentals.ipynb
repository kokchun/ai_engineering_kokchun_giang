# %% [markdown]
# # PydanticAI fundamentals

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

# GOOGLE_API_KEY or GEMINI_API_KEY should be defined in .env
agent = Agent(model="google-gla:gemini-2.5-flash")

result = await agent.run("Give me a programming joke")

result
# Out:
# AgentRunResult(output='Why do programmers prefer dark mode?\n\nBecause light attracts bugs!')

# %%
print(result.output)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs!

# %%
result = await agent.run("Give me an IT employee working in Sweden, shortly")
result
# Out:
# AgentRunResult(output="**Axel Karlsson**\n**Role:** DevOps Engineer\n**Location:** Stockholm, Sweden\n\nAxel works for a mid-sized tech company, automating cloud infrastructure and deployment pipelines. He's known for his calm efficiency, enjoys his daily *fika* breaks, and appreciates Sweden's focus on work-life balance, often spending his weekends hiking in nature.")

# %%
print(result.output)
# Out:
# **Axel Karlsson**
# **Role:** DevOps Engineer
# **Location:** Stockholm, Sweden
#
# Axel works for a mid-sized tech company, automating cloud infrastructure and deployment pipelines. He's known for his calm efficiency, enjoys his daily *fika* breaks, and appreciates Sweden's focus on work-life balance, often spending his weekends hiking in nature.

# %%
with open("employee.md", "w") as file:
    file.write(result.output)

# %% [markdown]
# ## pydantic to structure the output

# %%
from pydantic import BaseModel, Field

class EmployeeModel(BaseModel):
    name: str = Field(description="name of employee") 
    age: int = Field(description="age of employee", gt = 17, lt = 70)
    salary: int = Field(description="monthly salary of employee between 35000 and 70000", gt = 35000, lt=70000)
    role: str = Field(description="role of the employee, what he/she is working with")

# result = await agent.run("Give me an IT employee working in Sweden", output_type=EmployeeModel)
# result

# %%
employee = result.output
employee
# Out:
# EmployeeModel(name='Kalle Johansson', age=30, salary=40000, role='IT Consultant')

# %%
employee.name, employee.role
# Out:
# ('Kalle Johansson', 'IT Consultant')

# %%
isinstance(employee, EmployeeModel), isinstance(employee, BaseModel)
# Out:
# (True, True)

# %% [markdown]
# simulate more employees

# %%
result = await agent.run("""
                         Give me 10 employees in AI and data engineering field
                         Generate different roles, the more senior the role, the higher the salary
                         """,
                         output_type=list[EmployeeModel])

result
# Out:
# AgentRunResult(output=[EmployeeModel(name='Alice Smith', age=25, salary=38000, role='Junior Data Engineer'), EmployeeModel(name='Bob Johnson', age=28, salary=45000, role='Data Engineer'), EmployeeModel(name='Charlie Brown', age=35, salary=60000, role='Senior Data Engineer'), EmployeeModel(name='Diana Prince', age=26, salary=39000, role='Junior AI Engineer'), EmployeeModel(name='Ethan Hunt', age=30, salary=48000, role='AI Engineer'), EmployeeModel(name='Fiona Glenn', age=38, salary=62000, role='Senior AI Engineer'), EmployeeModel(name='George White', age=32, salary=52000, role='Machine Learning Engineer'), EmployeeModel(name='Hannah Green', age=40, salary=68000, role='Lead Data Scientist'), EmployeeModel(name='Ivan Petrov', age=37, salary=65000, role='AI Research Scientist'), EmployeeModel(name='Julia Roberts', age=42, salary=69999, role='Data Architect')])

# %%
result.output[0].model_dump()
# Out:
# {'name': 'Alice Smith',
#  'age': 25,
#  'salary': 38000,
#  'role': 'Junior Data Engineer'}
